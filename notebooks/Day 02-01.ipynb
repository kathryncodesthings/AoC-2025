# %%
test_input = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"

# %%
id_list = test_input.split(",")

print(id_list)
# Out:
# ['11-22', '95-115', '998-1012', '1188511880-1188511890', '222220-222224', '1698522-1698528', '446443-446449', '38593856-38593862', '565653-565659', '824824821-824824827', '2121212118-2121212124']

# %%
# test

string = "1111"

i = 0
total_duplicates = 0

# for variable in iterable

# problem with the below is that the duplicates can't overlap...

for index, char in enumerate(string):
    if string.find(char+char, index,len(string))>=0:
        total_duplicates +=1
    print(f"Loop number {index+1}")
        
print(total_duplicates)



string = "1111"

i = 0
total_duplicates = 0

# for variable in iterable

# problem with the below is that the duplicates can't overlap...

for index, char in enumerate(string):
    if string.find(char+char, index,len(string))>=0:
        total_duplicates +=1
    print(f"Loop number {index+1}")
        
print(total_duplicates)
# Out:
# Loop number 1
# Loop number 2
# Loop number 3
# Loop number 4
# 3

# %%
for index, char in enumerate(string):
    # print (index, char)
    # find how many characters are left in the string after the current character
    characters_left = len(string) - index
    i = 0
    print(f"At index {index}, and character {char}, there are {characters_left} characters left")
        
    for characters_left in string[how_many_characters_are_left
        check if there are two of the current character
    for how many character sare left
        check if there are duplicates of [current character to next up to end]
        
        
    #for characters_left in enumerate(string):
     #   i = i + 1
        # print(characters_left)
      #  print(f'Check for character \'{string[index]}\' from {index} to {i}')
       # x = string.find(string[index])
        #print(x)
        
    


#for i in id_list:
    # read in first range pair
    # extract first number
    # extract last number
    # loop through the range (inclusive)
        # for each number
        # test to see if there is a duplicate string of numbers:
            # loop through number of characters in string
                # for j characters in string (e.g. 10)
                    # check for char j x 2
